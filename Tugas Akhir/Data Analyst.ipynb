# %%
import pandas as pd
import seaborn as sns
import os

# %%
def dataspread(filename):
    df = pd.read_csv(filename, delimiter=';')
    print(filename)
    sns.pairplot(df)

# %%
for i in os.listdir('data/'):
    dataspread('data/'+i)
# Out:
# data/CB.csv
# data/LB.csv
# data/LW.csv
# data/P.csv
# data/RB.csv
# data/RW.csv
# Error in callback <function flush_figures at 0x00000105D7252F80> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File F:\Anaconda\lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File F:\Anaconda\lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
#      89     for figure_manager in Gcf.get_all_fig_managers():
# ---> 90         display(
# ...
